# %%
import json

# %%
data_dir = "/Users/yuqingz/Downloads/bdd100k/labels/det_20/"

# %%
fname = data_dir + 'det_train.json'
train = json.load(open(fname, "rb"))

# %%
len(train)
# Out:
# 69863

# %%
train[0]
# Out:
# {'name': '0000f77c-6257be58.jpg',
#  'attributes': {'weather': 'clear',
#   'timeofday': 'daytime',
#   'scene': 'city street'},
#  'timestamp': 10000,
#  'labels': [{'id': '0',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'G'},
#    'category': 'traffic light',
#    'box2d': {'x1': 1125.902264,
#     'y1': 133.184488,
#     'x2': 1156.978645,
#     'y2': 210.875445}},
#   {'id': '1',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'G'},
#    'category': 'traffic light',
#    'box2d': {'x1': 1156.978645,
#     'y1': 136.637417,
#     'x2': 1191.50796,
#     'y2': 210.875443}},
#   {'id': '2',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'NA'},
#    'category': 'traffic sign',
#    'box2d': {'x1': 1105.66915985699,
#     'y1': 211.122087,
#     'x2': 1170.79037,
#     'y2': 233.566141}},
#   {'id': '3',
#    'attributes': {'occluded': False,
# ...

# %%
fname = data_dir + 'det_val.json'
val = json.load(open(fname, "rb"))

# %%
len(val)
# Out:
# 10000

# %%
val[0]
# Out:
# {'name': 'b1c66a42-6f7d68ca.jpg',
#  'attributes': {'weather': 'overcast',
#   'timeofday': 'daytime',
#   'scene': 'city street'},
#  'timestamp': 10000,
#  'labels': [{'id': '0',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'NA'},
#    'category': 'traffic sign',
#    'box2d': {'x1': 1000.698742,
#     'y1': 281.992415,
#     'x2': 1040.626872,
#     'y2': 326.91156}},
#   {'id': '1',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'NA'},
#    'category': 'traffic sign',
#    'box2d': {'x1': 214.613695,
#     'y1': 172.190058,
#     'x2': 274.505889,
#     'y2': 229.586743}},
#   {'id': '2',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'NA'},
#    'category': 'traffic sign',
#    'box2d': {'x1': 797.314833,
#     'y1': 313.186265,
#     'x2': 829.756437,
#     'y2': 341.884608}},
#   {'id': '3',
#    'attributes': {'occluded': False,
# ...
